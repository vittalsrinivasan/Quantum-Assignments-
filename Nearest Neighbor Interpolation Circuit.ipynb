# %%
# %matplotlib inline
# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, execute, Aer, IBMQ
from qiskit.compiler import transpile, assemble
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from iqx import *

# Loading your IBM Q account(s)
provider = IBMQ.load_account()
# Out:
# /opt/conda/lib/python3.7/site-packages/qiskit/providers/ibmq/ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '

# %%
import numpy as np
from qiskit import QuantumCircuit, QuantumRegister, execute
from qiskit import BasicAer
from qiskit.tools.visualization import plot_bloch_multivector

qr1 = QuantumRegister(7)
circ = QuantumCircuit(qr1)

circ.barrier(qr1[0])
circ.barrier(qr1[3])
circ.barrier(qr1[4])
circ.reset(qr1[1])
circ.h(qr1[1])
circ.reset(qr1[2])
circ.h(qr1[2])
circ.barrier(qr1[5])
circ.reset(qr1[6])
circ.h(qr1[6])
# Use the BasicAer statevector_simulator backend

backend_sv_sim = BasicAer.get_backend('statevector_simulator')

job_sim = execute(circ, backend_sv_sim)
result_sim = job_sim.result()
quantum_state = result_sim.get_statevector(circ, decimals=3)

# Output the quantum state vector
print('State Vectors:')
print(quantum_state)
print()
# Draw the circuit
print("Circuit:")
circ.draw(output='mpl')
# Out:
# State Vectors:
# [0.35355339+0.j 0.        +0.j 0.35355339+0.j 0.        +0.j
#  0.35355339+0.j 0.        +0.j 0.35355339+0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j
# ...

# %%
from qiskit.visualization import plot_histogram
count=result_sim.get_counts(circ)
plot_histogram([count])

# %%
import numpy as np
from qiskit.circuit.library import MCXGate
from qiskit import QuantumCircuit, QuantumRegister, execute
from qiskit import BasicAer
from qiskit.tools.visualization import plot_bloch_multivector

from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi
from qiskit.circuit.library import C4XGate
from qiskit.circuit.library import MCXGate
from qiskit.visualization import plot_histogram

qr2 = QuantumRegister(14)
creg_c = ClassicalRegister(14)
circ1 = QuantumCircuit(qr2, creg_c)
circ1.barrier(qr2[0])
circ1.barrier(qr2[0])
circ1.reset(qr2[1])
circ1.h(qr2[1])
circ1.reset(qr2[2])
circ1.h(qr2[2])
circ1.barrier(qr2[3])
circ1.barrier(qr2[3])
circ1.barrier(qr2[4])
circ1.barrier(qr2[4])
circ1.barrier(qr2[5])
circ1.barrier(qr2[5])
circ1.barrier(qr2[6])
circ1.barrier(qr2[6])
circ1.barrier(qr2[7])
circ1.barrier(qr2[7])
circ1.barrier(qr2[8])
circ1.barrier(qr2[8])
circ1.barrier(qr2[9])
circ1.barrier(qr2[9])
circ1.barrier(qr2[10])
circ1.barrier(qr2[10])
circ1.barrier(qr2[11])
circ1.barrier(qr2[11])
circ1.reset(qr2[12])
circ1.h(qr2[12])
circ1.barrier(qr2[13])
circ1.barrier(qr2[13])


circ1.barrier(qr2[0])
circ1.barrier(qr2[1])
circ1.barrier(qr2[2])
circ1.reset(qr2[3])
circ1.reset(qr2[4])
circ1.barrier(qr2[5])
circ1.barrier(qr2[6])
circ1.reset(qr2[7])
circ1.reset(qr2[8])
circ1.reset(qr2[9])
circ1.reset(qr2[10])
circ1.barrier(qr2[11])
circ1.barrier(qr2[12])
circ1.reset(qr2[13])
circ1.h(qr2[3])
circ1.h(qr2[4])
circ1.h(qr2[13])
circ1.append(MCXGate(6),[qr2[0], qr2[1], qr2[2], qr2[3], qr2[4],qr2[5],qr2[7]])
circ1.append(MCXGate(6),[qr2[0], qr2[1], qr2[2], qr2[3], qr2[4],qr2[6],qr2[8]])
circ1.append(MCXGate(6),[qr2[0], qr2[1], qr2[2], qr2[3], qr2[4],qr2[5],qr2[7]])
circ1.append(MCXGate(6),[qr2[0], qr2[1], qr2[2], qr2[3], qr2[4],qr2[6],qr2[8]])
circ1.append(MCXGate(6),[qr2[0], qr2[1], qr2[2], qr2[3], qr2[4],qr2[5],qr2[7]])
circ1.append(MCXGate(6),[qr2[0], qr2[1], qr2[2], qr2[3], qr2[4],qr2[6],qr2[8]])
circ1.append(MCXGate(6),[qr2[0], qr2[1], qr2[2], qr2[3], qr2[4],qr2[5],qr2[7]])
circ1.append(MCXGate(6),[qr2[0], qr2[1], qr2[2], qr2[3], qr2[4],qr2[6],qr2[8]])

circ1.append(MCXGate(4),[qr2[7], qr2[11], qr2[12], qr2[13],qr2[9]])
circ1.append(MCXGate(4),[qr2[8], qr2[11], qr2[12], qr2[13],qr2[10]])
circ1.append(MCXGate(4),[qr2[7], qr2[11], qr2[12], qr2[13],qr2[9]])
circ1.append(MCXGate(4),[qr2[8], qr2[11], qr2[12], qr2[13],qr2[10]])
backend_sv_sim = BasicAer.get_backend('statevector_simulator')

job_sim = execute(circ1, backend_sv_sim)
result_sim = job_sim.result()
quantum_state = result_sim.get_statevector(circ1, decimals=3)

# Output the quantum state vector
print('State Vectors:')
print(quantum_state)
print()
# Draw the circuit
print("Circuit:")
circ.draw(output='mpl')
# Out:
# State Vectors:
# [0.125-2.12108377e-16j 0.   +0.00000000e+00j 0.125-1.24905058e-16j ...
#  0.   +0.00000000e+00j 0.   +0.00000000e+00j 0.   +0.00000000e+00j]
#
# Circuit:

# %%
count1=result_sim.get_counts(circ1)
plot_histogram([count1])

# %%
import numpy as np
from qiskit.circuit.library import MCXGate
from qiskit import QuantumCircuit, QuantumRegister, execute
from qiskit import BasicAer
from qiskit.tools.visualization import plot_bloch_multivector

from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi
from qiskit.circuit.library import C4XGate
from qiskit.circuit.library import MCXGate
from qiskit.visualization import plot_histogram

qr2 = QuantumRegister(15)
creg_c = ClassicalRegister(15)
circ2 = QuantumCircuit(qr2, creg_c)
circ2.barrier(qr2[0])
circ2.barrier(qr2[0])
circ2.reset(qr2[1])
circ2.h(qr2[1])
circ2.reset(qr2[2])
circ2.h(qr2[2])
circ2.barrier(qr2[3])
circ2.barrier(qr2[3])
circ2.barrier(qr2[4])
circ2.barrier(qr2[4])
circ2.barrier(qr2[5])
circ2.barrier(qr2[5])
circ2.barrier(qr2[6])
circ2.barrier(qr2[6])
circ2.barrier(qr2[7])
circ2.barrier(qr2[7])
circ2.barrier(qr2[8])
circ2.barrier(qr2[8])
circ2.barrier(qr2[9])
circ2.barrier(qr2[9])
circ2.barrier(qr2[10])
circ2.barrier(qr2[10])
circ2.barrier(qr2[11])
circ2.barrier(qr2[11])
circ2.reset(qr2[12])
circ2.h(qr2[12])
circ2.barrier(qr2[13])
circ2.barrier(qr2[13])

circ2.barrier(qr2[0])
circ2.barrier(qr2[1])
circ2.barrier(qr2[2])
circ2.reset(qr2[3])
circ2.reset(qr2[4])
circ2.barrier(qr2[5])
circ2.barrier(qr2[6])
circ2.reset(qr2[7])
circ2.reset(qr2[8])
circ2.reset(qr2[9])
circ2.reset(qr2[10])
circ2.barrier(qr2[11])
circ2.barrier(qr2[12])
circ2.reset(qr2[13])
circ2.h(qr2[3])
circ2.h(qr2[4])
circ2.h(qr2[13])
circ2.append(MCXGate(6),[qr2[0], qr2[1], qr2[2], qr2[3], qr2[4],qr2[5],qr2[7]])
circ2.append(MCXGate(6),[qr2[0], qr2[1], qr2[2], qr2[3], qr2[4],qr2[6],qr2[8]])
circ2.append(MCXGate(6),[qr2[0], qr2[1], qr2[2], qr2[3], qr2[4],qr2[5],qr2[7]])
circ2.append(MCXGate(6),[qr2[0], qr2[1], qr2[2], qr2[3], qr2[4],qr2[6],qr2[8]])
circ2.append(MCXGate(6),[qr2[0], qr2[1], qr2[2], qr2[3], qr2[4],qr2[5],qr2[7]])
circ2.append(MCXGate(6),[qr2[0], qr2[1], qr2[2], qr2[3], qr2[4],qr2[6],qr2[8]])
circ2.append(MCXGate(6),[qr2[0], qr2[1], qr2[2], qr2[3], qr2[4],qr2[5],qr2[7]])
circ2.append(MCXGate(6),[qr2[0], qr2[1], qr2[2], qr2[3], qr2[4],qr2[6],qr2[8]])

circ2.append(MCXGate(4),[qr2[7], qr2[11], qr2[12], qr2[13],qr2[9]])
circ2.append(MCXGate(4),[qr2[8], qr2[11], qr2[12], qr2[13],qr2[10]])
circ2.append(MCXGate(4),[qr2[7], qr2[11], qr2[12], qr2[13],qr2[9]])
circ2.append(MCXGate(4),[qr2[8], qr2[11], qr2[12], qr2[13],qr2[10]])

circ2.barrier(qr2[3])
circ2.barrier(qr2[4])
circ2.barrier(qr2[6])
circ2.barrier(qr2[6])
circ2.barrier(qr2[6])
circ2.barrier(qr2[6])
circ2.reset(qr2[6])
circ2.barrier(qr2[9])
circ2.barrier(qr2[10])
circ2.reset(qr2[11])
circ2.reset(qr2[12])
circ2.barrier(qr2[13])

circ2.h(qr2[6])
circ2.append(MCXGate(4),[qr2[3], qr2[4], qr2[6], qr2[9],qr2[11]])
circ2.append(MCXGate(4),[qr2[3], qr2[4], qr2[6], qr2[10],qr2[12]])
circ2.append(MCXGate(4),[qr2[3], qr2[4], qr2[6], qr2[9],qr2[11]])
circ2.append(MCXGate(4),[qr2[3], qr2[4], qr2[6], qr2[10],qr2[12]])

circ2.barrier(qr2[14])
circ2.barrier(qr2[14])
circ2.barrier(qr2[14])
circ2.barrier(qr2[14])
circ2.barrier(qr2[14])
circ2.barrier(qr2[14])
circ2.barrier(qr2[14])
circ2.barrier(qr2[14])
circ2.barrier(qr2[14])
circ2.barrier(qr2[14])
circ2.barrier(qr2[14])
circ2.barrier(qr2[14])
circ2.barrier(qr2[14])
circ2.barrier(qr2[14])
circ2.barrier(qr2[14])
circ2.barrier(qr2[14])


circ2.reset(qr2[14])
circ2.barrier(qr2[14])
circ2.barrier(qr2[14])
circ2.barrier(qr2[14])
circ2.barrier(qr2[14])
circ2.barrier(qr2[14])
circ2.h(qr2[14])





backend_sv_sim = BasicAer.get_backend('statevector_simulator')

job_sim = execute(circ2, backend_sv_sim)
result_sim = job_sim.result()
quantum_state = result_sim.get_statevector(circ2, decimals=3)

# Output the quantum state vector
print('State Vectors:')
print(quantum_state)
print()
# Draw the circuit
print("Circuit:")
circ2.draw(output='mpl')
# Out:
# State Vectors:
# [0.08838835-1.33784298e-16j 0.        +0.00000000e+00j
#  0.08838835-1.14292322e-16j ... 0.        +0.00000000e+00j
#  0.        +0.00000000e+00j 0.        +0.00000000e+00j]
#
# Circuit:

# %%
count2=result_sim.get_counts(circ2)
plot_histogram([count2])
